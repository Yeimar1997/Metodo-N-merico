# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeimar1997/Metodo-n-merico/blob/master/Algoritmo_estadisticas_Metodos_n%C3%BAmerico_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estadística
#
# * La estadística es la ciencia que estudia cómo debe emplearse la información y cómo dar una guía de acción en situaciones prácticas que entrañan incertidumbre.
#
# * La estadística podría definirse como la ciencia que se encarga de recopilar, organizar, procesar, analizar e interpretar datos con el fin de deducir las características de un grupo o población objetivo.
#
# # Tipos de estadística
#
# ***Estadística descriptiva***
#
# La estadística descriptiva se puede definir como un método para describir numéricamente conjuntos numerosos. Por tratarse de un método de descripción numérica, utiliza el número como medio para describir un conjunto, que debe ser numeroso, ya que las permanencias estadísticas no se dan en los casos raros.
#
# ***Estadística inferencial, analítica o deductiva***
#
# La estadística inferencial estudia la probabilidad de éxito de las diferentes soluciones posibles a un problema en las diferentes ciencias en las que se aplica y para ello utiliza los datos observados en una o varias muestras de la población.

# %% [markdown]
# # Medidas de centralización
#
# Para calcular estas medidas, simplemente seleccionamos la variable estadística del DataFrame y usamos los métodos mean, median y mode respectivamente.
#
# ### Cálculo de promedios y de valores medios
#
# **La media:** Se define como la suma de N elementos dividida entre N. Se trata una medida bastante conocida entre la gente, aunque tiene el inconveniente de que es muy susceptible a valores extremos.
#
# ***Media: mean(data)***
#
# La función **mean()** devuelve la media aritmética de los datos de una muestra o población. Esta media se calcula sumando todos los valores y después el resultado de la suma se divide entre el número de elementos.
#
# **Algoritmo**

# %%
import statistics as stats

edades = [46, 54, 42, 46, 32, 30]
print(stats.mean(edades))
# Out:
# 41.666666666666664

# %% [markdown]
# **La mediana:** Es el valor que dentro del conjunto de datos es menor que el 50% de los datos y mayor que el 50% restante.
#
# ***Mediana: median(data)***
#
# La función **median()** devuelve la mediana o valor medio de los datos. La mediana es el valor central de un grupo de números ordenados por tamaño. Si la cantidad de elementos es par, la mediana es el promedio de los dos números centrales.
#
# **Algoritmo**

# %%
Dias = [22, 23, 26, 26, 26, 34, 34, 38]
print(stats.median(Dias))
# Out:
# 26.0

# %% [markdown]
# **La moda:** Es el valor más repetido (solo aplicable a variables discretas).
#
# ***Moda: mode(data)***
#
# La función **mode()** devuelve el valor más frecuente de los datos.
#
# **Algoritmo**

# %%
edades = [22, 23, 26, 26, 26, 34, 34, 38, 40, 41, 38, 38, 38, 22, 12, 23, 22, 25]
print(stats.mode(edades))
# Out:
# 38

# %% [markdown]
# # Medidas de dispersión
#
# **varianza:**La varianza es la media de las diferencias con la media elevadas al cuadrado.
#
# ***Varianza (población): pvariance(data, mu=None)***
#
# La función **pvariance()** devuelve la varianza de una población de datos. Esta función es equivalente a variance() pero se aplica a una población en lugar de a una muestra. La función pvariance() para obtener la varianza primero calcula la media de los elementos:
#
# edades = [22, 23, 26, 26, 26, 34, 34, 38, 40, 41]
# media = (22 + 23 + 26 + 26 + 26 + 34 + 34 + 38 + 40 + 41) / 10 = 31
#
# A cada número se le resta la media obtenida y se eleva al cuadrado. Después, se suman todos los resultados:
#
# dif_cuadrado = (22-31)**2 + (23-31)**2 + (26-31)**2 + (26-31)**2 + (26-31)**2 + (34-31)**2 + (34-31)**2 + (38-31)**2 + (40-31)**2 + (41-31)**2 = 468
#
# Finalmente, se calcula la media de todas las diferencias al cuadrado:
#
# varianza = 468 / 10 = 46.8
#
# **Algoritmo**

# %%
edades = [22, 23, 26, 26, 36, 34, 34, 38, 40, 41]
print(stats.pvariance(edades))
# Out:
# 45.8

# %% [markdown]
# ***Varianza (muestra): variance(data, xbar=None)***
#
# La función variance() devuelve la varianza de una muestra de datos. La varianza mide en qué medida se dispersan los valores de una muestra alrededor de un valor central.
#
# El argumento xbar es opcional y si se facilita debe ser la media de los datos. En caso contrario, la función calculará este dato automáticamente.
#
# Para calcular la varianza de una población entera utilizar la función pvariance().
#
# **Algoritmo**

# %%
muestra_edades = [22, 35, 26, 12, 34, 38, 42]
print(stats.variance(muestra_edades))
# Out:
# 108.80952380952381

# %% [markdown]
# # Tipos de Tipos de gráficos
#
# Un  gráfico  estadístico  es  una  representación  visual  de  una  serie  de  datos  estadísticos.
#
# **grafico de barra**
#
# * Este grafico representa  los datos  cualitativos de una distribución
#
# * Un gráfico de barras es una representación gráfica en un eje cartesiano de las frecuencias de una variable cualitativa o discreta.
#
# **Algortimo de un ejemplo**
#
# **Ejemplo**
#
# Tenemos una muestra de 50  ventas de refresco realizar el diagrama de barra y el diagrama de torta
#
# **Algoritmo**

# %%
import numpy as np
import matplotlib.pyplot as plt

bebidas = ['Coke classic', 'Died coke', 'Dr pepper', 'Pepsi', 'sprite'] #Nombres de las bebidas 
Cantidad = [19, 8, 5, 13, 5] # Nro Cantidades

plt.bar(range(5), Cantidad, edgecolor='black')

plt.xticks(range(5), bebidas, rotation=60)
plt.title("REFRESCOS")
plt.ylim(min(Cantidad)-1, max(Cantidad)+1) #Muestra la cantidades en la grafica 
plt.show()

# %% [markdown]
# **Diagrama de torta**
#
# * Esta grafica representa  datos  resumidos  mediante una distribucion de frecuencia.
#
# * Un gráfico de pastel es un gráfico circular, el cual está dividido de tal manera que se asemeja a las tajadas de un pastel.
#
# * Este gráfico divide tus datos en sectores, ilustrando cada proporción numérica con el fin de mostrar la composición como un todo.

# %%
cantidad = [19, 8, 5, 13, 5]
bebidas = ['Coke classic', 'Died coke', 'Dr pepper', 'Pepsi', 'sprite']

explode = [0.38, 0.16, 0.1, 0.26, 0.1]  #Sirve para separar quesitos del centro de la tarta

plt.pie(cantidad, labels=bebidas, explode=explode,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('REFRESCOS')
plt.show()

# %% [markdown]
# **Grafico de torta 2**
#
# Nombres de personas y cantidad de libros

# %%
import matplotlib.pyplot as plt

libros = [12,7,23,20,25,30]
nombres = ["Alex","Frank ","Maria","Catalina","Juanito","Marta"]
plt.pie(libros, labels=nombres)
plt.pie(libros, labels=nombres, autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %% [markdown]
# ***Diagramas de caja y bigotes***
#
# * Un diagrama de cajas y bigotes es una manera conveniente de mostrar visualmente grupos de datos numéricos a través de sus cuartiles.
#
# Las líneas que se extienden paralelas a las cajas se conocen como «bigotes», y se usan para indicar variabilidad fuera de los cuartiles superior e inferior. Los valores atípicos se representan a veces como puntos individuales que están en línea con los bigotes. Los diagramas de cajas y bigotes se pueden dibujar vertical u horizontalmente.
#
# los gráficos de cajas y bigotes son una excelente forma de examinar rápidamente uno o más conjuntos de datos gráficamente. Aunque parezcan primitivos en comparación con un Histograma o un Gráfico de Densidad, tienen la ventaja de ocupar menos espacio, lo cual es útil cuando se comparan distribuciones entre muchos grupos o conjuntos de datos.
#
#
# **Algoritmo**

# %%
import matplotlib.pyplot as plt
import numpy as np

X1 = np.random.normal(0, 1, 500)
X2 = np.random.normal(0.3, 1, 500)

# El diagrama de caja simple
plt.boxplot(X1)
plt.show()

# Cambiar características
plt.boxplot(X1, notch=True, sym="o") # Use sym="" to shown no fliers; also showfliers=False
plt.show()

# Mostrar múltiples diagramas de caja en la misma ventana
plt.boxplot((X1, X2), notch=True, sym="o", labels=["Set 1", "Set 2"])
plt.show()

# Personalización avanzada de la gráfica de caja
line_props = dict(color="r", alpha=0.3)
bbox_props = dict(color="g", alpha=0.9, linestyle="dashdot")
flier_props = dict(marker="o", markersize=17)
plt.boxplot(X1, notch=True, whiskerprops=line_props, boxprops=bbox_props, flierprops=flier_props)
plt.show()

# %% [markdown]
# # Distribuciones de probabilidad
#
# * Es una función que asigna a cada suceso definido sobre la variable la probabilidad de que dicho suceso ocurra.
#
# * Las distribuciones de probabilidad teóricas son útiles en la inferencia estadística porque sus propiedades y características son conocidas. Si la distribución real de un conjunto de datos dado es razonablemente cercana a la de una distribución de probabilidad teórica, muchos de los cálculos se pueden realizar en los datos reales utilizando hipótesis extraídas de la distribución teórica.
#
# ![distribution.png](attachment:distribution.png)

# %% [markdown]
# ![texto alternativo](https://)# Graficando distribuciones
#
# **Histogramas**
#
# Es una de las mejores maneras de describir una variable es representar los valores que aparecen en el conjunto de datos y el número de veces que aparece cada valor.
#
# En Python, podemos graficar fácilmente un histograma con la ayuda de la función hist de matplotlib, simplemente debemos pasarle los datos y la cantidad de contenedores en los que queremos dividirlos. Por ejemplo, podríamos graficar el histograma de una distribución normal del siguiente modo.
#
# ### Algotimo

# %%
# importando modulos necesarios
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns 

np.random.seed(2016) # replicar random

# parametros esteticos de seaborn
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})
# Graficando histograma
mu, sigma = 0, 0.2 # media y desvio estandar
datos = np.random.normal(mu, sigma, 1000) #Creacion de muestra de datos

# Histograma de distribución normal.
cuenta, cajas, ignorar = plt.hist(datos, 20)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Histograma')
plt.show()

# %% [markdown]
# ## Distribuciones Discretas
#
# Las distribuciones discretas son aquellas en las que la variable puede tomar solo algunos valores determinados. Los principales exponentes de este grupo son las siguientes:
#
# ***Distribución Poisson***
#
# La Distribución Poisson esta dada por la formula: En dónde r es un entero (r≥0) y μ es un número real positivo.
# ![sdsdsd.png](attachment:sdsdsd.png)
#
# En Python la podemos generar fácilmente con la ayuda de **scipy.stats**, paquete que utilizaremos para representar a todas las restantes distribuciones a lo largo de todo el artículo.
#
# ### Algortimos

# %%
# Graficando Poisson
mu =  3.6 # parametro de forma 
poisson = stats.poisson(mu) # Distribución
x = np.arange(poisson.ppf(0.01),
              poisson.ppf(0.99))
fmp = poisson.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# histograma
aleatorios = poisson.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Histograma Poisson')
plt.show()

# %% [markdown]
# ## Distribución Binomial
#
# La Distribución Binomial esta dada por la formula: En dónde r con la condición 0≤r≤N y el parámetro N (N>0) son enteros; y el parámetro p (0≤p≤1) es un número real.
#
# ![sdsdsd.png](attachment:sdsdsd.png)
#
#
# ### Algotimo

# %%
# Graficando Binomial
N, p = 30, 0.4 # parametros de forma 
binomial = stats.binom(N, p) # Distribución
x = np.arange(binomial.ppf(0.01),
              binomial.ppf(0.99))
fmp = binomial.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Binomial')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# Histograma
aleatorios = binomial.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Histograma Binomial')
plt.show()
